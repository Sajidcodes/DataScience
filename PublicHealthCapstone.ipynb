# %% [markdown]
# <a href="https://colab.research.google.com/github/Sajidcodes/DataScience/blob/main/PublicHealthCapstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing necessary libraries
import pandas as pd

# fetching the url where the dataset is located
# Pre-cleaned version on Kaggle (requires Kaggle API key)
# OR use this CDC direct CSV — age-adjusted prevalence, no login:
url = "https://data.cdc.gov/api/views/d2rk-yvas/rows.csv?accessType=DOWNLOAD"


# loading the dataset
df = pd.read_csv(url)

# printing the rows and columns of the dataset
print(f"Shape: {df.shape[0]} rows × {df.shape[1]} columns")

# displaying 5 random values
df.sample(5)
# Out:
# Shape: 86481 rows × 27 columns
#        Year Locationabbr   Locationdesc                      Class  \
# 83108  2024           MN      Minnesota  Chronic Health Indicators
# 19027  2014           MA  Massachusetts             Women's Health
# 78707  2023           PR    Puerto Rico                   HIV-AIDS
# 35290  2016           VT        Vermont  Chronic Health Indicators
# 6517   2012           ME          Maine  Chronic Health Indicators
#
#                         Topic  \
# 83108  Cardiovascular Disease
# 19027               Mammogram
# 78707                HIV Test
# 35290  Cardiovascular Disease
# 6517               Depression
#
#                                                 Question  \
# 83108  Respondents that have ever reported having cor...
# 19027  Women aged 50+ who have had a mammogram within...
# 78707                 Have you ever been tested for HIV?
# 35290  Ever told you had angina or coronary heart dis...
# 6517   Ever told you that you have a form of depression?
#
#                               Response Break_Out Break_Out_Category  \
# 83108  Did not report having MI or CHD   Overall            Overall
# 19027                              Yes   Overall            Overall
# 78707                               No   Overall            Overall
# 35290                               No   Overall            Overall
# 6517                                No   Overall            Overall
#
#        Sample_Size  ...  Data_Value_Footnote  DataSource  ClassId  TopicId  \
# 83108        13824  ...                  NaN       BRFSS  CLASS03  TOPIC10
# 19027         4936  ...                  NaN       BRFSS  CLASS18  Topic37
# 78707         1753  ...                  NaN       BRFSS  CLASS09  TOPIC32
# 35290         6173  ...                  NaN       BRFSS  CLASS03  TOPIC10
# 6517          7679  ...                  NaN       BRFSS  CLASS03  Topic17
#
#       LocationID BreakoutID BreakOutCategoryID QuestionID RESPONSEID  \
# 83108         27        BO1               CAT1     _MICHD    RESP204
# 19027         25        BO1               CAT1   _MAM502Y    RESP046
# 78707         72        BO1               CAT1    HIVTST7    RESP054
# 35290         50        BO1               CAT1   CVDCRHD4    RESP054
# 6517          23        BO1               CAT1   ADDEPEV2    RESP054
#
#                                    Geolocation
# 83108  (46.35564873600049, -94.79420050299967)
# 19027             (42.27687047, -72.082690675)
# 78707                  (18.220833, -66.590149)
# 35290  (43.62538123900049, -72.51764079099962)
# 6517          (45.254228894001, -68.985031336)
#
# [5 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Year                              0
# Locationabbr                      0
# Locationdesc                      0
# Class                             0
# Topic                             0
# Question                          0
# Response                          0
# Break_Out                         0
# Break_Out_Category                0
# Sample_Size                       0
# Data_value                      605
# Confidence_limit_Low            605
# Confidence_limit_High           605
# Display_order                     0
# Data_value_unit                   0
# Data_value_type                   0
# Data_Value_Footnote_Symbol    85876
# Data_Value_Footnote           85876
# DataSource                        0
# ClassId                           0
# TopicId                           0
# LocationID                        0
# BreakoutID                        0
# BreakOutCategoryID                0
# QuestionID                        0
# RESPONSEID                        0
# Geolocation                       0
# dtype: int64
